# %%
from pathlib import Path

# %%
from textblob import TextBlob

# %%
blob=TextBlob(Path('RomeoAndJuliet.txt').read_text())

# %%
blob.word_counts
# Out:
# defaultdict(int,
#             {'project': 90,
#              'gutenbergâ€™s': 1,
#              'romeo': 304,
#              'and': 809,
#              'juliet': 183,
#              'by': 143,
#              'william': 4,
#              'shakespeare': 6,
#              'this': 271,
#              'ebook': 11,
#              'is': 367,
#              'for': 250,
#              'the': 876,
#              'use': 25,
#              'of': 519,
#              'anyone': 5,
#              'anywhere': 3,
#              'in': 395,
#              'united': 15,
#              'states': 19,
#              'most': 21,
#              'other': 32,
#              'parts': 4,
#              'world': 17,
#              'at': 83,
#              'no': 112,
#              'cost': 4,
#              'with': 301,
#              'almost': 5,
#              'restrictions': 2,
#              'whatsoever': 2,
#              'you': 364,
#              'may': 63,
#              'copy': 12,
# ...

# %%
blob.word_counts['juliet'] #Word Count in all sentences of paragraph
# Out:
# 183

# %%
blob.words.count('joy')
# Out:
# 14

# %%
blob.noun_phrases.count('lady capulet')
# Out:
# 46

# %%
#Getting Definitions Synonyms and Antonyms from Wordet
#Deleting Stop Words

# %%
from textblob import Word

# %%
happy=Word('happy')

# %%
happy.definitions
# Out:
# ['enjoying or showing or marked by joy or pleasure',
#  'marked by good fortune',
#  'eagerly disposed to act or to be of service',
#  'well expressed and to the point']

# %%
happy.synsets
# Out:
# [Synset('happy.a.01'),
#  Synset('felicitous.s.02'),
#  Synset('glad.s.02'),
#  Synset('happy.s.04')]

# %%
synonyms=set()

# %%
for synset in happy.synsets:
    for lemma in synset.lemmas():
        synonyms.add(lemma.name())

# %%
synonyms
# Out:
# {'felicitous', 'glad', 'happy', 'well-chosen'}

# %%
lemmas=happy.synsets[0].lemmas()

# %%
lemmas
# Out:
# [Lemma('happy.a.01.happy')]

# %%
lemmas[0].antonyms()
# Out:
# [Lemma('unhappy.a.01.unhappy')]

# %%
# Deleting Stop Words

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\RN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
stops=stopwords.words('english')

# %%
sorted(stops)
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
blob=TextBlob('Today is a beautiful day.')

# %%
[word for word in blob.words if word not in stops]
# Out:
# ['Today', 'beautiful', 'day']

# %%
#n-Grams next lecture

# %%
text='Today is a beautiful day. Tomorrow looks like bad weather'

# %%
blob=TextBlob(text)

# %%
blob.ngrams()
# Out:
# [WordList(['Today', 'is', 'a']),
#  WordList(['is', 'a', 'beautiful']),
#  WordList(['a', 'beautiful', 'day']),
#  WordList(['beautiful', 'day', 'Tomorrow']),
#  WordList(['day', 'Tomorrow', 'looks']),
#  WordList(['Tomorrow', 'looks', 'like']),
#  WordList(['looks', 'like', 'bad']),
#  WordList(['like', 'bad', 'weather'])]

# %%
blob.ngrams(n=5)
# Out:
# [WordList(['Today', 'is', 'a', 'beautiful', 'day']),
#  WordList(['is', 'a', 'beautiful', 'day', 'Tomorrow']),
#  WordList(['a', 'beautiful', 'day', 'Tomorrow', 'looks']),
#  WordList(['beautiful', 'day', 'Tomorrow', 'looks', 'like']),
#  WordList(['day', 'Tomorrow', 'looks', 'like', 'bad']),
#  WordList(['Tomorrow', 'looks', 'like', 'bad', 'weather'])]

# %%
#Next lession Visualizing word frequencies with bar charts and word clouds
